# %%
# Required imports
import gempy as gp
import gempy_viewer as gpv
import pandas as pd
import geopandas as gpd
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.sample import sample_gen
import pyvista as pv
# Out:
# Setting Backend To: AvailableBackends.numpy

# %%
data_path = "../Tables/North"

# Path to the text file
file_path = data_path + "/Clipped/North_1_Int.txt"

# Load the data into a pandas DataFrame
df = pd.read_csv(file_path, sep=',')
df
# Out:
#        Id             formation          X           Y        Z  \
# 0     0.0    Paleogene_Volcanic  482791.46  2151825.08   -44.02
# 1     0.0    Paleogene_Volcanic  483183.46  2151825.08   -19.67
# 2     0.0      Neogene_Volcanic  482649.57  2151825.08   427.48
# 3     0.0   Quaternary_alluvial  485893.28  2151825.08  1873.28
# 4     0.0        Quaternary_Lac  483803.68  2151825.08  1942.57
# ...   ...                   ...        ...         ...      ...
# 1839  0.0   Quaternary_volcanic  481592.27  2199688.38  1754.61
# 1840  0.0           Neogene_Lac  483933.15  2199688.38  1983.26
# 1841  0.0  Cretaceous_limestone  483891.65  2199688.38 -1000.00
# 1842  0.0  Cretaceous_limestone  496121.46  2199688.38 -1000.00
# 1843  0.0    Paleogene_Volcanic  496121.46  2199688.38   921.82
#
#                           geometry
# 0     POINT (482791.46 2151825.08)
# 1     POINT (483183.46 2151825.08)
# 2     POINT (482649.57 2151825.08)
# 3     POINT (485893.28 2151825.08)
# 4     POINT (483803.68 2151825.08)
# ...                            ...
# 1839  POINT (481592.27 2199688.38)
# 1840  POINT (483933.15 2199688.38)
# 1841  POINT (483891.65 2199688.38)
# 1842  POINT (496121.46 2199688.38)
# 1843  POINT (496121.46 2199688.38)
#
# [1844 rows x 6 columns]

# %%
# Read the shapefile
file_path = '../Shapefiles/'
polygon_all = gpd.read_file(file_path + 'Model_Zones.shp')

# Filter by attribute value, for example 'Middle_1'
polygon = polygon_all[polygon_all['Zones'] == 'North_1']

# Get the boundaries
x_min = polygon.bounds.minx.min()
y_min = polygon.bounds.miny.min()
x_max = polygon.bounds.maxx.max()
y_max = polygon.bounds.maxy.max()

# %%
# Find the maximum value
z_max = df['Z'].max()

# Find the minimum value
z_min = df['Z'].min()

print("x_max:", x_max, "y_max:", y_max, "z_max:", z_max)
print("x_min:", x_min, "y_min:", y_min, "z_min:", z_min)
# Out:
# x_max: 498539.01305389125 y_max: 2200072.8645330574 z_max: 2994.0
# x_min: 455132.92356009316 y_min: 2156558.971936483 z_min: -1000.0

# %%
dx=25
dy=25
dz=50

Lx= x_max-x_min
Ly= y_max-y_min
Lz= z_max-z_min

print(Lx/dx, Ly/dy, Lz/dz)
# Out:
# 1736.2435797519238 1740.55570386298 79.88

# %%
geo_model = gp.create_geomodel(
    project_name='model',
    extent=[x_min, x_max, y_min, y_max, z_min - dz, z_max + dz],
    resolution=[dx, dy, dz],
    importer_helper=gp.data.ImporterHelper(
        path_to_surface_points=data_path + "/Clipped/North_1_Int.txt",  
        path_to_orientations=data_path + "/Clipped/North_1_Ori.txt"     
    )
)

# %%
# Display a basic cross section of input data
gpv.plot_2d(geo_model)
# Out:
# c:\Users\juanc\miniconda3\envs\gempy3\Lib\site-packages\gempy_viewer\API\_plot_2d_API.py:174: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
# View structural frame
geo_model.structural_frame
# Out:
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=default_formation,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Cretaceous_limestone,
# 	color=#015482,
# 	is_active=True
# ),
# Element(
# 	name=F1,
# 	color=#9f0052,
# 	is_active=True
# ),
# Element(
# 	name=F10,
# 	color=#ffbe00,
# 	is_active=True
# ),
# Element(
# 	name=F6,
# 	color=#728f02,
# 	is_active=True
# ),
# Element(
# 	name=F9,
# 	color=#443988,
# 	is_active=True
# ),
# Element(
# 	name=MxF,
# 	color=#ff3f20,
# 	is_active=True
# ),
# Element(
# 	name=NF,
# 	color=#5DA629,
# 	is_active=True
# ),
# Element(
# 	name=Neogene_Lac,
# 	color=#b271d0,
# 	is_active=True
# ),
# Element(
# 	name=Neogene_Volcanic,
# 	color=#72e54a,
# 	is_active=True
# ),
# Element(
# 	name=Neogene_pyro,
# 	color=#583bd1,
# 	is_active=True
# ),
# Element(
# 	name=Paleogene_Volcanic,
# 	color=#d0e63d,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_Lac,
# 	color=#b949e2,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_Pyro2,
# 	color=#95ce4b,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_alluvial,
# 	color=#6d2b9f,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_volcanic,
# 	color=#60eb91,
# 	is_active=True
# ),
# Element(
# 	name=TF,
# 	color=#d746be,
# 	is_active=True
# ),
# Element(
# 	name=ToF,
# 	color=#52a22e,
# 	is_active=True
# ),
# Element(
# 	name=ZF,
# 	color=#5e63d8,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False]],

# %%
del_surfaces = ["ZF","Cretaceous_limestone", "F1"]
for s in del_surfaces:
    gp.remove_element_by_name(geo_model, s)

geo_model.structural_frame
# Out:
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=default_formation,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=F10,
# 	color=#ffbe00,
# 	is_active=True
# ),
# Element(
# 	name=F6,
# 	color=#728f02,
# 	is_active=True
# ),
# Element(
# 	name=F9,
# 	color=#443988,
# 	is_active=True
# ),
# Element(
# 	name=MxF,
# 	color=#ff3f20,
# 	is_active=True
# ),
# Element(
# 	name=NF,
# 	color=#5DA629,
# 	is_active=True
# ),
# Element(
# 	name=Neogene_Lac,
# 	color=#b271d0,
# 	is_active=True
# ),
# Element(
# 	name=Neogene_Volcanic,
# 	color=#72e54a,
# 	is_active=True
# ),
# Element(
# 	name=Neogene_pyro,
# 	color=#583bd1,
# 	is_active=True
# ),
# Element(
# 	name=Paleogene_Volcanic,
# 	color=#d0e63d,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_Lac,
# 	color=#b949e2,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_Pyro2,
# 	color=#95ce4b,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_alluvial,
# 	color=#6d2b9f,
# 	is_active=True
# ),
# Element(
# 	name=Quaternary_volcanic,
# 	color=#60eb91,
# 	is_active=True
# ),
# Element(
# 	name=TF,
# 	color=#d746be,
# 	is_active=True
# ),
# Element(
# 	name=ToF,
# 	color=#52a22e,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False]],

# %%
# Define structural groups and age/stratigraphic relationship
gp.map_stack_to_surfaces(
    gempy_model=geo_model,
    mapping_object={
        "Q_L":("Quaternary_Lac"),
        "Q_a":("Quaternary_alluvial"),
        "N_L":("Neogene_Lac"),
        "Q_P":("Quaternary_Pyro2"),
        "Q_V":( "Quaternary_volcanic"),


        "MxF":("MxF"),
        "NF":("NF"),
        "TF":("TF"),
        "F6":("F6"),
        "F9":("F9"),
        "F10":("F10"),
        "ToF":("ToF"),

        "N_P":("Neogene_pyro"),
        "N_V": ("Neogene_Volcanic"),
        "P_V": ("Paleogene_Volcanic"),
    }
)
# Out:
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=Q_L,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_Lac,
# 	color=#b949e2,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Q_a,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_alluvial,
# 	color=#6d2b9f,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=N_L,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Neogene_Lac,
# 	color=#b271d0,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Q_P,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_Pyro2,
# 	color=#95ce4b,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Q_V,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_volcanic,
# 	color=#60eb91,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=MxF,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=MxF,
# 	color=#ff3f20,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=NF,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=NF,
# 	color=#5DA629,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=TF,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=TF,
# 	color=#d746be,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=F6,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=F6,
# 	color=#728f02,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=F9,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=F9,
# 	color=#443988,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=F10,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=F10,
# 	color=#ffbe00,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=ToF,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=ToF,
# 	color=#52a22e,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=N_P,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Neogene_pyro,
# 	color=#583bd1,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=N_V,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Neogene_Volcanic,
# 	color=#72e54a,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=P_V,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Paleogene_Volcanic,
# 	color=#d0e63d,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False]],

# %%
# Define group as fault
gp.set_is_fault(geo_model, ["MxF","ToF","NF","TF","F9","F10","F6"]) #,"F1","ToF"
# Out:
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=Q_L,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_Lac,
# 	color=#b949e2,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Q_a,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_alluvial,
# 	color=#6d2b9f,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=N_L,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Neogene_Lac,
# 	color=#b271d0,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Q_P,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_Pyro2,
# 	color=#95ce4b,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=Q_V,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Quaternary_volcanic,
# 	color=#60eb91,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=MxF,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=MxF,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=NF,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=NF,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=TF,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=TF,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=F6,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=F6,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=F9,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=F9,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=F10,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=F10,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=ToF,
# 	structural_relation=StackRelationType.FAULT,
# 	elements=[
# Element(
# 	name=ToF,
# 	color=#527682,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=N_P,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Neogene_pyro,
# 	color=#583bd1,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=N_V,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Neogene_Volcanic,
# 	color=#72e54a,
# 	is_active=True
# )
# ]
# ),
# StructuralGroup(
# 	name=P_V,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=Paleogene_Volcanic,
# 	color=#d0e63d,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False,  True,  True,  True],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False],
#  [False, False, False, False, False, False, False, False, False, False,
#   False, False, False, False, False]],

# %%
# Compute model
gp.compute_model(geo_model)
# Out:
# Setting Backend To: AvailableBackends.numpy
# Chunking done: 39 chunks
# Chunking done: 63 chunks
# Chunking done: 15 chunks
# Chunking done: 16 chunks
# Chunking done: 34 chunks
# Chunking done: 55 chunks
# Chunking done: 55 chunks
# Chunking done: 7 chunks
# Chunking done: 11 chunks
# Chunking done: 6 chunks
# Chunking done: 10 chunks
# Chunking done: 10 chunks
# Chunking done: 7 chunks
# Chunking done: 11 chunks
# Chunking done: 6 chunks
# Chunking done: 10 chunks
# Chunking done: 10 chunks
# Chunking done: 41 chunks
# Chunking done: 66 chunks
# Chunking done: 15 chunks
# Chunking done: 16 chunks
# Chunking done: 36 chunks
# Chunking done: 57 chunks
# Chunking done: 57 chunks
# Chunking done: 6 chunks
# Chunking done: 7 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 7 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 7 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 8 chunks
# Chunking done: 7 chunks
# Chunking done: 7 chunks
# Chunking done: 6 chunks
# Chunking done: 9 chunks
# Chunking done: 7 chunks
# Chunking done: 8 chunks
# Solutions(4 Octree Levels, 15 DualContouringMeshes)

# %%
gpv.plot_2d(geo_model, cell_number=0, show_data=False, direction='y', ve=3)
# Out:
# c:\Users\juanc\miniconda3\envs\gempy3\Lib\site-packages\gempy_viewer\API\_plot_2d_API.py:174: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gpv.plot_3d(geo_model, show_lith=True, show_data=False, show_boundaries=True)

# %%
p = gpv.plot_3d(geo_model, show_data=False, show_results=True, show_boundaries=True,image=True)

# %% [markdown]
# ### Migration to vtk

# %%
box = p.regular_grid_actor.GetMapper().GetInput() # Get the vtk file for the regular grid

# === Load the DEM ===
with rasterio.open("../Dataset/Raster/cdmx.tif") as src:
    out_image, out_transform = mask(src, polygon.geometry, crop=True)
    elev = out_image[0].astype(float)
    transform = out_transform

    # Mark nodata values
    elev[elev == src.nodata] = np.nan   

    # Create X, Y coordinates
    nrows, ncols = elev.shape
    x = np.arange(ncols) * transform.a + transform.c
    y = np.arange(nrows) * transform.e + transform.f
    #y = y[::-1]  # Invertir eje Y para corregir orientación
    x, y = np.meshgrid(x, y)

# === Flatten and filter valid points ===
x_flat = x.ravel()
y_flat = y.ravel()
z_flat = elev.ravel()

valid_mask = np.isfinite(z_flat)
points = np.c_[x_flat[valid_mask], y_flat[valid_mask], z_flat[valid_mask]]

# === Create 3D Mesh ===
cloud = pv.PolyData(points)
surface = cloud.delaunay_2d()

# === Create a closed mesh from the DEM ===
surface = surface.elevation()  # ensures that it has scalar values
surface = surface.triangulate()

# === Cut the block with the surface ===
block_cortado = box.clip_surface(surface, invert=True)

block_cortado.save("../Results/North_1.vtk")

# %% [markdown]
# ### Migration to numpy array

# %%
# 1. Get the coordinates (x, y, z) of the grid
coordinates = geo_model.grid.regular_grid.values  # This is of form [n, 3], where each row is [x, y, z]

# 2. Obtain the lithology block
lith_block = geo_model.solutions.raw_arrays.lith_block  # This is a 1D array with the lithology IDs

# 3. Obtaining the names of lithologies from surfaces
lithology_names = geo_model.structural_frame.elements_names  # List of names of lithologies

# Make sure the number of coordinates and lithologies match
assert len(coordinates) == len(lith_block), "The dimensions of the coordinates and lithologies do not match."

# 4. Create the DataFrame with the information
data = []

# Traverse each voxel and associate the coordinates with the lithology
for i in range(len(coordinates)):
    x, y, z = coordinates[i]  # Coordinates
    lith_id = lith_block[i]  # Lithology ID
    
    # Check if the lithology ID is within the range of names
    if lith_id - 1 < len(lithology_names):
        lith_name = lithology_names[lith_id - 1]  # Name of the lithology
    else:
        lith_name = "Desconocida"  # If the ID is out of range, assign a generic name
    
    # Add the row with x, y, z, id and lithology name
    data.append([x, y, z, lith_id, lith_name])

# Create a DataFrame with the results
df = pd.DataFrame(data, columns=['x', 'y', 'z', 'id', 'lithology_name'])

# Load the DEM
with rasterio.open("../Dataset/Raster/cdmx.tif") as dem:
    # Extract elevation from the DEM at points (x, y)
    coords = [(x, y) for x, y in zip(df['x'], df['y'])]
    elevaciones_dem = list(dem.sample(coords))
    # Convertir de lista de listas a lista plana
    df['elev_dem'] = [val[0] if val else None for val in elevaciones_dem]

# Filter: Keep only points with z <= DEM elevation
df_filtrado = df[df['z'] <= df['elev_dem']]

# Save the result
df_filtrado.to_csv(("../Results/North_1.txt"),index=False)

# %%
# "MxF","NF","TF","F9","F10","F6"
p.surface_poly['MxF'].save('../Faults/North_1/MxF.vtk')
p.surface_poly['ToF'].save('../Faults/North_1/ToF.vtk')
p.surface_poly['TF'].save('../Faults/North_1/TF.vtk')
p.surface_poly['F9'].save('../Faults/North_1/F9.vtk')
p.surface_poly['F10'].save('../Faults/North_1/F10.vtk')
p.surface_poly['F6'].save('../Faults/North_1/F6.vtk')
